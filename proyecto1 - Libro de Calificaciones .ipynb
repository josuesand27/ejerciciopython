# %% [markdown]
# ## Libro de calificaciones
#
# #### Eres un estudiante y estás tratando de organizar tus materias y calificaciones usando Python. Exploremos lo que hemos aprendido sobre las listas para organizar sus materias y puntajes.
#
#
# ## Create Some Lists:
#
# 1. Crea una lista llamada subjects y complétala con las clases que estás tomando:
#
#
#     "physics"
#     "calculus"
#     "poetry"
#     "history"
#
#
# 2. Crea una lista llamada gradesy complétala con tus puntajes:
#
#
#     98
#     97
#     85
#     88
#
#
#
# 3. Manualmente (sin ningún método) cree una lista bidimensional para combinar subjectsy grades. Utilice la siguiente tabla como referencia para los valores asociados. Asigne el valor a una variable llamada gradebook
#
# ![image.png](attachment:image.png)
#
#
# 4. Imprimir gradebook
#
#     ¿Se ve como esperabas que sería?
#
#
# ## Add More Subjects:
#
#
# 5. ¡Tu calificación para tu clase de informática acaba de llegar! ¡Obtuviste una puntuación perfecta 100!
#
#     Use el .append() método para agregar una lista con los valores de "computer science" y un valor de calificación asociado de 100 a nuestra lista bidimensional de gradebook.
#
#
#
# 6. ¡Tu calificación para "visual arts" acaba de llegar! ¡Tienes un 93!
#
#     Úse append para agregar ["visual arts", 93] a gradebook.
#
#
# ## Modify The Gradebook:
#
#
# 7. Nuestro instructor nos acaba de decir que cometieron un error al calificar y están otorgando 5 puntos adicionales para nuestra clase de artes visuales.
#
#     Accede al índice de la nota de tu clase de artes visuales y modifícala para que sea 5 puntos mayor.
#
#
# 8. Decidió cambiar de un valor de calificación numérico a una opción de Aprobado/Reprobado para su clase de poesía.
#
#     Encuentre el valor de calificación en su gradebookclase de poesía y use el .remove()método para eliminarlo.
#
#
# 9. Use el .append()método para luego agregar un nuevo "Pass"valor a la sublista donde se encuentra su clase de poesía.
#
#
# ## One Big Gradebook!
#
#
# 10. También tienes tus calificaciones del último semestre, almacenadas en last_semester_gradebook.
#
#     Cree una nueva variable full_gradebookque combine ambos last_semester_gradebooky gradebookuse +para tener un libro de calificaciones completo.
#
#     Imprima full_gradebookpara ver nuestra lista completa.

# %%
last_semester_gradebook = [["politics", 80], ["latin", 96], ["dance", 97], ["architecture", 65]]

# Your code below:

# %%
#1
subjects=["physics","calculus","poetry","history"]

# %%
#2
gradesy=[98,97,85,88]

# %%
#3
gradebook=[
    [subjects[0],gradesy[0]],
    [subjects[1],gradesy[1]],
    [subjects[2],gradesy[2]],
    [subjects[3],gradesy[3]], 
    ]
#4
print(gradebook)
# Out:
# [['physics', 98], ['calculus', 97], ['poetry', 85], ['history', 88]]

# %%
#5
gradebook.append(["computer science",100])
print (gradebook)
# Out:
# [['physics', 98], ['calculus', 97], ['poetry', 85], ['history', 88], ['computer science', 100]]

# %%
#6
gradebook.append(["visual arts", 93] )
print (gradebook)
# Out:
# [['physics', 98], ['calculus', 97], ['poetry', 85], ['history', 88], ['computer science', 100], ['visual arts', 93]]

# %%
#7
gradebook[-1][-1]+=5
print (gradebook)
# Out:
# [['physics', 98], ['calculus', 97], ['poetry', 85], ['history', 88], ['computer science', 100], ['visual arts', 98]]

# %%
#8
gradebook[2].remove(85)

# %%
#9
gradebook[2].append("pass")

# %%
print(gradebook)
# Out:
# [['physics', 98], ['calculus', 97], ['poetry', 'pass'], ['history', 88], ['computer science', 100], ['visual arts', 98]]

# %%
#10
full_gradebook=last_semester_gradebook+gradebook

print(full_gradebook)
# Out:
# [['politics', 80], ['latin', 96], ['dance', 97], ['architecture', 65], ['physics', 98], ['calculus', 97], ['poetry', 'pass'], ['history', 88], ['computer science', 100], ['visual arts', 98]]
