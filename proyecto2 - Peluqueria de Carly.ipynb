# %% [markdown]
# # Peluqueria de Carly
#
# ### Usted es el analista de datos de Carly's Clippers, la peluquería más nueva de la cuadra. Su trabajo es revisar las listas de datos que se han recopilado en las últimas dos semanas. Estarás calculando algunas métricas importantes que Carly puede usar para planificar la operación del negocio para el resto del mes.
#
# ## Se le han proporcionado tres listas:
#
# #### hairstyles: los nombres de los cortes ofrecidos en Carly's Clippers.
#
# #### prices: el precio de cada peinado de la hairstyleslista.
#
# #### last_week: el número de compras para cada tipo de peinado en la última semana.
#
# ### Cada índice en hairstylescorresponde a un índice asociado en pricesy last_week.
#
# ### Por ejemplo, el peinado "bouffant"tiene un precio asociado de 30la priceslista y se compró 2veces en la última semana como se muestra en la last_weeklista. Cada uno de estos elementos se encuentran en el primer índice de sus respectivas listas.
#
# # ¡Empecemos!
#
#
#
# ## Prices and Cuts:
#
#
# 1. Carly quiere poder comercializar sus precios bajos. Queremos saber cuál es el precio medio de un corte.
#
#     Primero, resumamos todos los precios de los cortes de pelo. Cree una variable total_price y configúrela en 0.
#
#
# 2. Recorra la prices lista y agregue cada precio a la variable total_price.
#
#
# 3. Después de su bucle, cree una variable llamada average_priceque se total_pricedivida por el número de precios.
#
#     Puede obtener el número de precios utilizando la len()función.
#
#
# 4. Imprima el valor de average_pricepara que la salida se vea así:
#
# ![image.png](attachment:image.png)
#
#
# 5. ¡Ese precio promedio es más caro de lo que Carly pensó que sería! Ella quiere reducir todos los precios en 5 dólares.
#
#     Use una lista de comprensión para hacer una lista llamada new_prices, que tiene cada elemento en prices menos 5.
#
#
# 6. Imprimir new_prices.
#
#
# ## Revenue:
#
#
# 7. Carly realmente quiere asegurarse de que Carly's Clippers sea un esfuerzo rentable. Primero quiere saber cuántos ingresos se generaron la semana pasada.
#
#     Cree una variable llamada total_revenue y configúrela en 0.
#
#
# 8. Use un forbucle para crear una variable i que vaya de 0 a len(hairstyles)
#
#     Sugerencia: ¡Puedes usar range()para hacer esto!
#
#
# 9. Agregue el producto de prices[i] (el precio del corte de cabello en la posición i) y last_week[i] (el número de personas que se cortaron el cabello en la posición i) total_revenueb en cada paso.
#
#
# 10. Después de su ciclo, imprima el valor de total_revenue, para que la salida se vea así:
#
# ![image-2.png](attachment:image-2.png)
#
#
# 11. Encuentre el ingreso diario promedio dividiéndolo total_revenue por 7. Llame a este número average_daily_revenuee imprímalo.
#
#
# 12. Carly cree que puede atraer a más clientes publicitando todos los cortes de cabello que tiene por menos de 30 dólares.
#
#     Use una lista de comprensión para crear una lista llamada cuts_under_30 que tenga la entrada hairstyles[i] para cada uno i de los cuales new_prices[i] es menor que 30.
#
#     Puedes usar range() en tu lista de comprensión para hacer i ir de 0 a len(new_prices) - 1.
#
#
# 13. Imprimir cuts_under_30

# %%
hairstyles = ["bouffant", "pixie", "dreadlocks", "crew", "bowl", "bob", "mohawk", "flattop"]

prices = [30, 25, 40, 20, 20, 35, 50, 35]

last_week = [2, 3, 5, 8, 4, 4, 6, 2]
